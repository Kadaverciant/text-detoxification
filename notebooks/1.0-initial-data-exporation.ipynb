# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data exploration

# %%
df = pd.read_csv("../data/raw/filtered.tsv", sep="\t", index_col=0)

# %%
df.head(10)
# Out:
#                                            reference  \
# 0  If Alkar is flooding her with psychic waste, t...
# 1                          Now you're getting nasty.
# 2           Well, we could spare your life, for one.
# 3          Ah! Monkey, you've got to snap out of it.
# 4                   I've got orders to put her down.
# 5  I'm not gonna have a child... ...with the same...
# 6  They're all laughing at us, so we'll kick your...
# 7    Maine was very short on black people back then.
# 8                 Briggs, what the hell's happening?
# 9  Another one simply had no clue what to do, so ...
#
#                                          translation  similarity  lenght_diff  \
# 0  if Alkar floods her with her mental waste, it ...    0.785171     0.010309
# 1                        you're becoming disgusting.    0.749687     0.071429
# 2                      well, we can spare your life.    0.919051     0.268293
# 3                       monkey, you have to wake up.    0.664333     0.309524
# 4                         I have orders to kill her.    0.726639     0.181818
# 5  I'm not going to breed kids with a genetic dis...    0.703185     0.206522
# 6            they're laughing at us. We'll show you.    0.618866     0.230769
# 7             there wasn't much black in Maine then.    0.720482     0.187500
# 8                 Briggs, what the hell is going on?    0.920373     0.000000
# 9  another simply didn't know what to do, so when...    0.877540     0.101695
#
#     ref_tox   trn_tox
# 0  0.014195  0.981983
# 1  0.065473  0.999039
# 2  0.213313  0.985068
# 3  0.053362  0.994215
# 4  0.009402  0.999348
# 5  0.950956  0.035846
# 6  0.999492  0.000131
# 7  0.963680  0.148710
# 8  0.159096  0.841071
# 9  0.055371  0.930472

# %%
len(df)
# Out:
# 577777

# %% [markdown]
# It seems there is typo in lenght_diff column, let's fix it.

# %%
df = df.rename(columns={'lenght_diff': 'length_diff'})

# %% [markdown]
# For our task it doesn't matter, whether reference or translation sentence was toxic or not. We also want to work with high level of toxicity, therefore I suggest:
# - Get all entries where ```ref_tox```> ```toxicity_threshold``` and ```trn_tox```< ```non_toxicity_threshold```, rename ```reference``` column as ```toxic``` and ```translation``` column as ```non-toxic```
# - Get all entries where ```trn_tox```> ```toxicity_threshold``` and ```ref_tox```< ```non_toxicity_threshold``` , rename ```reference``` column as ```non-toxic``` and ```translation``` column as ```toxic```
# - Concatenate entries of resulting tables

# %%
toxicity_threshold, non_toxicity_threshold = 0.95, 0.05
df_ref_tox = df[(df['ref_tox'] > toxicity_threshold) & (df['trn_tox'] < non_toxicity_threshold)]
df_ref_tox = df_ref_tox.rename(columns={'reference': 'toxic', 'translation': 'non-toxic', 'ref_tox':'toxic_metric', 'trn_tox':'non-toxic_metric'})
print(len(df_ref_tox))
df_ref_tox.head()
# Out:
# 207661
#                                                 toxic  \
# 5   I'm not gonna have a child... ...with the same...
# 6   They're all laughing at us, so we'll kick your...
# 13               Come on, Cal, leave that shit alone.
# 22     Real life starts the first time you fuck, kid.
# 25             Shit, this one I can't even pronounce.
#
#                                             non-toxic  similarity  \
# 5   I'm not going to breed kids with a genetic dis...    0.703185
# 6             they're laughing at us. We'll show you.    0.618866
# 13                         come on, Cal, put it down.    0.660481
# 22                    boy, real life starts up first.    0.866697
# 25                 gosh, I can't even pronounce this.    0.777253
#
#     length_diff  toxic_metric  non-toxic_metric
# 5      0.206522      0.950956          0.035846
# 6      0.230769      0.999492          0.000131
# 13     0.270270      0.999637          0.000279
# 22     0.319149      0.998222          0.000114
# 25     0.102564      0.997452          0.000120

# %%
toxicity_threshold, non_toxicity_threshold = 0.95, 0.05
df_trn_tox = df[(df['ref_tox'] < non_toxicity_threshold) & (df['trn_tox'] > toxicity_threshold)]
df_trn_tox = df_trn_tox.rename(columns={'reference': 'non-toxic', 'translation': 'toxic', 'ref_tox':'non-toxic_metric', 'trn_tox':'toxic_metric'})
print(len(df_trn_tox))
df_trn_tox.head()
# Out:
# 142044
#                                             non-toxic  \
# 0   If Alkar is flooding her with psychic waste, t...
# 4                    I've got orders to put her down.
# 10  I suppose you want me to buy you flowers and c...
# 14                               So he's the Top dog.
# 15  I swore when I went out with Xander Harris... ...
#
#                                                 toxic  similarity  \
# 0   if Alkar floods her with her mental waste, it ...    0.785171
# 4                          I have orders to kill her.    0.726639
# 10  you'd probably want me to buy you some chocola...    0.800661
# 14                   he's the tallest son of a bitch.    0.611092
# 15  when I was dating Alex Harris, I swore I'd rat...    0.790565
#
#     length_diff  non-toxic_metric  toxic_metric
# 0      0.010309          0.014195      0.981983
# 4      0.181818          0.009402      0.999348
# 10     0.160000          0.000078      0.980341
# 14     0.363636          0.000920      0.999639
# 15     0.148936          0.011613      0.996266

# %% [markdown]
# Now let's rearrange columns

# %%
df_trn_tox = df_trn_tox[['toxic', 'non-toxic', 'similarity', 'length_diff', 'toxic_metric', 'non-toxic_metric']]
print(len(df_trn_tox))
df_trn_tox.head()
# Out:
# 142044
#                                                 toxic  \
# 0   if Alkar floods her with her mental waste, it ...
# 4                          I have orders to kill her.
# 10  you'd probably want me to buy you some chocola...
# 14                   he's the tallest son of a bitch.
# 15  when I was dating Alex Harris, I swore I'd rat...
#
#                                             non-toxic  similarity  \
# 0   If Alkar is flooding her with psychic waste, t...    0.785171
# 4                    I've got orders to put her down.    0.726639
# 10  I suppose you want me to buy you flowers and c...    0.800661
# 14                               So he's the Top dog.    0.611092
# 15  I swore when I went out with Xander Harris... ...    0.790565
#
#     length_diff  toxic_metric  non-toxic_metric
# 0      0.010309      0.981983          0.014195
# 4      0.181818      0.999348          0.009402
# 10     0.160000      0.980341          0.000078
# 14     0.363636      0.999639          0.000920
# 15     0.148936      0.996266          0.011613

# %%
df_united = pd.concat([df_ref_tox, df_trn_tox])
print(len(df_united))
df_united.head()
# Out:
# 349705
#                                                 toxic  \
# 5   I'm not gonna have a child... ...with the same...
# 6   They're all laughing at us, so we'll kick your...
# 13               Come on, Cal, leave that shit alone.
# 22     Real life starts the first time you fuck, kid.
# 25             Shit, this one I can't even pronounce.
#
#                                             non-toxic  similarity  \
# 5   I'm not going to breed kids with a genetic dis...    0.703185
# 6             they're laughing at us. We'll show you.    0.618866
# 13                         come on, Cal, put it down.    0.660481
# 22                    boy, real life starts up first.    0.866697
# 25                 gosh, I can't even pronounce this.    0.777253
#
#     length_diff  toxic_metric  non-toxic_metric
# 5      0.206522      0.950956          0.035846
# 6      0.230769      0.999492          0.000131
# 13     0.270270      0.999637          0.000279
# 22     0.319149      0.998222          0.000114
# 25     0.102564      0.997452          0.000120

# %% [markdown]
# Let's check that everything concatenated correctly.

# %%
print(len(df_united[df_united['toxic_metric'] > df_united['non-toxic_metric']]))
# Out:
# 349705

# %% [markdown]
# We also don't want to work with very similar sentences, for that purpose let's exclude everything, which has ```similarity``` > ```similarity_threshold``` and ```length_diff``` < ```length_diff_threshold```.
#
# However, we firstly need to check what data we'd exclude by this actions, in order to get more or less suitable thresholds.

# %%
similarity_threshold, length_diff_threshold = 0.9, 0.5

df_similar = df_united[(df_united['similarity'] >= similarity_threshold) & (df_united['length_diff'] <= length_diff_threshold)]
print(len(df_similar))
df_similar.head()
# Out:
# 20943
#                                                  toxic  \
# 41    It told you this was a waste of my fucking time.
# 43   I swear to God, the best thing I ever did in m...
# 60                          Your girlfriends are dead.
# 152  I can't believe we haven't fucked for two year...
# 185                 "Crap, I don't have time for this.
#
#                                              non-toxic  similarity  \
# 41             I told you this was a waste of my time.    0.904062
# 43   I swear to God, the best thing I've ever done ...    0.932305
# 60                              your friends are dead.    0.915111
# 152  I can't believe we haven't had sex in two year...    0.936891
# 185                 "hell, I don't have time for this.    0.921785
#
#      length_diff  toxic_metric  non-toxic_metric
# 41      0.183673      0.995877          0.000479
# 43      0.022472      0.999071          0.000900
# 60      0.148148      0.993116          0.012461
# 152     0.032967      0.988648          0.017638
# 185     0.000000      0.991890          0.004620

# %% [markdown]
# As we can see, with such thresholds we loose some suitable entries. Let's try to tighter them.

# %%
similarity_threshold, length_diff_threshold = 0.93, 0.2

df_similar = df_united[(df_united['similarity'] >= similarity_threshold) & (df_united['length_diff'] <= length_diff_threshold)]
print(len(df_similar))
df_similar.head()
# Out:
# 4232
#                                                  toxic  \
# 43   I swear to God, the best thing I ever did in m...
# 152  I can't believe we haven't fucked for two year...
# 741  I got to get the fuck out of here before I hur...
# 774  A favor to cover up your fuck up or a favor fo...
# 801  And do me a favor, would you sign the damn loa...
#
#                                              non-toxic  similarity  \
# 43   I swear to God, the best thing I've ever done ...    0.932305
# 152  I can't believe we haven't had sex in two year...    0.936891
# 741    I have to get out of here before I hurt anyone.    0.932508
# 774  a favor to cover up for screwing up, or a favo...    0.936666
# 801   would you do me a favor and sign the loan forms?    0.945823
#
#      length_diff  toxic_metric  non-toxic_metric
# 43      0.022472      0.999071          0.000900
# 152     0.032967      0.988648          0.017638
# 741     0.172414      0.981877          0.001174
# 774     0.067797      0.997602          0.000676
# 801     0.109091      0.999448          0.000045

# %% [markdown]
# It seem's that we shouldn't exclude anything.
#
# Then let's save our pairs of toxic and non-toxic sentences.

# %%
df_final = df_united[['toxic', 'non-toxic']]
df_final.head()
# Out:
#                                                 toxic  \
# 5   I'm not gonna have a child... ...with the same...
# 6   They're all laughing at us, so we'll kick your...
# 13               Come on, Cal, leave that shit alone.
# 22     Real life starts the first time you fuck, kid.
# 25             Shit, this one I can't even pronounce.
#
#                                             non-toxic
# 5   I'm not going to breed kids with a genetic dis...
# 6             they're laughing at us. We'll show you.
# 13                         come on, Cal, put it down.
# 22                    boy, real life starts up first.
# 25                 gosh, I can't even pronounce this.

# %%
df_final.to_csv("../data/raw/suitable.csv")
